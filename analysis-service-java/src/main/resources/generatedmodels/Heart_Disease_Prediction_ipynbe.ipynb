# %% [markdown]
# # Common

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
seed = 1111
np.random.seed(seed)

# %% [markdown]
# # Data Preparation

# %%
file_path = "/content/drive/MyDrive/Dataset/heart_statlog_cleveland_hungary_final.csv"
df = pd.read_csv(file_path)

# %%
df.head(5)
# Out:
#    age  sex  chest pain type  ...  oldpeak  ST slope  target
# 0   40    1                2  ...      0.0         1       0
# 1   49    0                3  ...      1.0         2       1
# 2   37    1                2  ...      0.0         1       0
# 3   48    0                4  ...      1.5         2       1
# 4   54    1                3  ...      0.0         1       0
#
# [5 rows x 12 columns]

# %%
# renaming features to proper name
df.columns = ['age', 'sex', 'chest_pain_type', 'resting_blood_pressure', 
              'cholesterol', 'fasting_blood_sugar', 'rest_ecg', 
              'max_heart_rate_achieved', 'exercise_induced_angina', 
              'st_depression', 'st_slope','target']

# %%
DROP = ['cholesterol', 'rest_ecg', 'st_depression', 'st_slope']
CONTI_COLS = ['age', 'sex', 'resting_blood_pressure', 
              'fasting_blood_sugar',
              'exercise_induced_angina', 'max_heart_rate_achieved'
              ]

CATE_COLS = ['chest_pain_type']
LABEL_COLS = "target"

# %%
df = df.drop(labels=DROP, axis=1)

# %%
# converting features to categorical features 
df['chest_pain_type'][df['chest_pain_type'] == 1] = 'typical_angina'
df['chest_pain_type'][df['chest_pain_type'] == 2] = 'atypical_angina'
df['chest_pain_type'][df['chest_pain_type'] == 3] = 'non_anginal_pain'
df['chest_pain_type'][df['chest_pain_type'] == 4] = 'asymptomatic'

# %%
df.head(5)
# Out:
#    age  sex  ... exercise_induced_angina  target
# 0   40    1  ...                       0       0
# 1   49    0  ...                       0       1
# 2   37    1  ...                       0       0
# 3   48    0  ...                       1       1
# 4   54    1  ...                       0       0
#
# [5 rows x 8 columns]

# %% [markdown]
# # Data Visualization

# %%
# Importing libraries for visualization data
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
df.shape
# Out:
# (1190, 8)

# %%
# summary statistics of numerical columns
df.describe(include =[np.number])
# Out:
#                age          sex  ...  exercise_induced_angina       target
# count  1190.000000  1190.000000  ...              1190.000000  1190.000000
# mean     53.720168     0.763866  ...                 0.387395     0.528571
# std       9.358203     0.424884  ...                 0.487360     0.499393
# min      28.000000     0.000000  ...                 0.000000     0.000000
# 25%      47.000000     1.000000  ...                 0.000000     0.000000
# 50%      54.000000     1.000000  ...                 0.000000     1.000000
# 75%      60.000000     1.000000  ...                 1.000000     1.000000
# max      77.000000     1.000000  ...                 1.000000     1.000000
#
# [8 rows x 7 columns]

# %%
# summary statistics of numerical columns
df.describe(include =[np.object])
# Out:
#        chest_pain_type
# count             1190
# unique               4
# top       asymptomatic
# freq               625

# %%
#Exploring the Heart Disease patients based on Chest Pain Type
plot_criteria= ['chest_pain_type', 'target']
cm = sns.light_palette("red", as_cmap=True)
(round(pd.crosstab(df[plot_criteria[0]], df[plot_criteria[1]], normalize='columns') * 100,2)).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
# #T_599d65d2_e7c9_11eb_9680_0242ac1c0002row0_col0{
#             background-color:  #fb5050;
#             color:  #000000;
#         }#T_599d65d2_e7c9_11eb_9680_0242ac1c0002row0_col1,#T_599d65d2_e7c9_11eb_9680_0242ac1c0002row2_col0{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_599d65d2_e7c9_11eb_9680_0242ac1c0002row1_col0{
#             background-color:  #fe0c0c;
#             color:  #f1f1f1;
#         }#T_599d65d2_e7c9_11eb_9680_0242ac1c0002row1_col1{
#             background-color:  #f3eded;
#             color:  #000000;
#         }#T_599d65d2_e7c9_11eb_9680_0242ac1c0002row2_col1{
#             background-color:  #f5cece;
#             color:  #000000;
#         }#T_599d65d2_e7c9_11eb_9680_0242ac1c0002row3_col0,#T_599d65d2_e7c9_11eb_9680_0242ac1c0002row3_col1{
#             background-color:  #f3f0f0;
#             color:  #000000;
#         }</style><table id="T_599d65d2_e7c9_11eb_9680_0242ac1c0002" ><thead>    <tr>        <th class="index_name level0" >target</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >chest_pain_type</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_599d65d2_e7c9_11eb_9680_0242ac1c0002level0_row0" class="row_heading level0 row0" >asymptomatic</th>
#                         <td id="T_599d65d2_e7c9_11eb_9680_0242ac1c0002row0_col0" class="data row0 col0" >25.310000</td>
#                         <td id="T_599d65d2_e7c9_11eb_9680_0242ac1c0002row0_col1" class="data row0 col1" >76.790000</td>
#             </tr>
#             <tr>
#                         <th id="T_599d65d2_e7c9_11eb_9680_0242ac1c0002level0_row1" class="row_heading level0 row1" >atypical_angina</th>
#                         <td id="T_599d65d2_e7c9_11eb_9680_0242ac1c0002row1_col0" class="data row1 col0" >32.980000</td>
#                         <td id="T_599d65d2_e7c9_11eb_9680_0242ac1c0002row1_col1" class="data row1 col1" >4.930000</td>
#             </tr>
#             <tr>
#                         <th id="T_599d65d2_e7c9_11eb_9680_0242ac1c0002level0_row2" class="row_heading level0 row2" >non_anginal_pain</th>
#                         <td id="T_599d65d2_e7c9_11eb_9680_0242ac1c0002row2_col0" class="data row2 col0" >34.400000</td>
#                         <td id="T_599d65d2_e7c9_11eb_9680_0242ac1c0002row2_col1" class="data row2 col1" >14.310000</td>
#             </tr>
#             <tr>
#                         <th id="T_599d65d2_e7c9_11eb_9680_0242ac1c0002level0_row3" class="row_heading level0 row3" >typical_angina</th>
#                         <td id="T_599d65d2_e7c9_11eb_9680_0242ac1c0002row3_col0" class="data row3 col0" >7.310000</td>
#                         <td id="T_599d65d2_e7c9_11eb_9680_0242ac1c0002row3_col1" class="data row3 col1" >3.970000</td>
#             </tr>
#     </tbody></table>

# %%
df['target'].value_counts()
# Out:
# 1    629
# 0    561
# Name: target, dtype: int64

# %%
# Any empty values?
df.isnull().sum()
# Out:
# age                        0
# sex                        0
# chest_pain_type            0
# resting_blood_pressure     0
# fasting_blood_sugar        0
# max_heart_rate_achieved    0
# exercise_induced_angina    0
# target                     0
# dtype: int64

# %%
plt.figure(figsize=[10, 5])
plt.title('Heart Disease Count for Target')
sns.countplot(x='target', data=df)
plt.legend(["Normal", "Heart Disease"])
plt.show()

# %%
pd.crosstab(df.age,df.target).plot(kind="bar",figsize=(10,5))
plt.title('Heart Disease Frequency for Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.savefig('heartDiseaseAndAges.png')
plt.show()

# %%
pd.crosstab(df.chest_pain_type,df.target).plot(kind="bar",figsize=(10,5),color=['#11A5AA','#AA1190' ])
plt.title('Heart Disease Frequency According To Chest Pain Type')
plt.xlabel('Chest Pain Type')
plt.xticks(rotation = 0)
plt.ylabel('Frequency of Disease or Not')
plt.show()

# %%
pd.crosstab(df.fasting_blood_sugar, df.target).plot(kind="bar",figsize=(10,5),color=['#11A5AA','#AA1190' ])
plt.title('Heart Disease Frequency According To Blood Sugar')
plt.xlabel('Blood Sugar')
plt.ylabel('Frequency of Disease or Not')
plt.show()

# %%
#Plotting the distribution plot.
plt.figure(figsize=(20,25))
plotnumber=1

for column in df:
  if plotnumber<14:
    ax=plt.subplot(4,4,plotnumber)
    sns.histplot(df[column])
    plt.xlabel(column,fontsize=20)
    plt.ylabel('Values',fontsize=20)
  plotnumber+=1
plt.show()

# %%
#Correlation matrix

plt.figure(figsize = (10, 5))

corr = df.corr()
mask = np.triu(np.ones_like(corr, dtype = bool))
sns.heatmap(corr, mask = mask, annot = True, fmt = '.2g', linewidths = 1)
plt.show()

# %% [markdown]
# # Data Pre-prosseing

# %%
## encoding categorical variables
df = pd.get_dummies(df)

df.head(5)
# Out:
#    age  sex  ...  chest_pain_type_non_anginal_pain  chest_pain_type_typical_angina
# 0   40    1  ...                                 0                               0
# 1   49    0  ...                                 1                               0
# 2   37    1  ...                                 0                               0
# 3   48    0  ...                                 0                               0
# 4   54    1  ...                                 1                               0
#
# [5 rows x 11 columns]

# %%
# Select the columns to use for prediction in the neural network
X = df.drop('target', axis=1)
Y = df[['target']]
print(X.shape, Y.shape, X.columns)
# Out:
# (1190, 10) (1190, 1) Index(['age', 'sex', 'resting_blood_pressure', 'fasting_blood_sugar',
#        'max_heart_rate_achieved', 'exercise_induced_angina',
#        'chest_pain_type_asymptomatic', 'chest_pain_type_atypical_angina',
#        'chest_pain_type_non_anginal_pain', 'chest_pain_type_typical_angina'],
#       dtype='object')

# %% [markdown]
# # Model Building

# %%
# Importing libraries for building the neural network
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import ModelCheckpoint

from sklearn import metrics
from sklearn.model_selection import StratifiedKFold
from keras.backend import clear_session

# %%
save_dir = '/content/saved_models/'

# %%
# !rm -f /content/saved_models/*

# %%
def get_model_name(k):
    return 'best_trained_model_'+str(k)+'.h5'

# %%
def getModel():
  model = Sequential()
  model.add(Dense(32, input_dim=10, kernel_initializer ='uniform', 
                  activation='relu'))
  model.add(Dropout(0.1))
  model.add(Dense(12, kernel_initializer ='uniform', activation='relu'))
  model.add(Dropout(0.2))
  model.add(Dense(1, kernel_initializer ='uniform', activation='sigmoid'))

  return model

# %% [markdown]
# ## Model Description

# %%
des = getModel()
des.compile(loss='binary_crossentropy', 
              optimizer="Adamax", 
              metrics=['accuracy'])
des.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                352
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                396
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 13
# =================================================================
# Total params: 761
# Trainable params: 761
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(des, show_shapes=True, rankdir="TB")

# %% [markdown]
# ## K-Fold Cross Validation

# %%
# Use for StratifiedKFold classification
kf = StratifiedKFold(5, shuffle=True, random_state=1111) 

fold = 0

for train, test in kf.split(X, Y):
  print("# Fold {}\n".format(fold))

  x_train = X.iloc[train]
  y_train = Y.iloc[train]
  x_test = X.iloc[test]
  y_test = Y.iloc[test]

  model = getModel()
  model.compile(loss='binary_crossentropy', 
                optimizer="Adamax", 
                metrics=['accuracy'])

  checkpoint = ModelCheckpoint(save_dir+get_model_name(fold), 
                                verbose=0, 
                                monitor='val_loss',
                                save_best_only=True, 
                                mode='auto')
  callbacks = [checkpoint]
  
  model.fit(x_train, y_train,
            verbose=0,
            validation_split=0.25, 
            epochs=200, 
            batch_size=16,
            callbacks=callbacks)

  print("Evaluate model against trained data")
  loss, accuracy = model.evaluate(x_train, y_train, verbose=0)
  print("accuracy: %.2f%%" % (accuracy*100))

  print("\nEvaluate model against new data")
  loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
  print("accuracy: %.2f%%" % (accuracy*100))

  clear_session()

  fold+=1

  print("\n")
# Out:
# # Fold 0
#
# Evaluate model against trained data
# accuracy: 81.20%
#
# Evaluate model against new data
# accuracy: 80.25%
#
#
# # Fold 1
#
# Evaluate model against trained data
# accuracy: 81.62%
#
# Evaluate model against new data
# accuracy: 76.89%
#
#
# # Fold 2
#
# Evaluate model against trained data
# accuracy: 79.41%
#
# Evaluate model against new data
# accuracy: 79.41%
#
#
# # Fold 3
#
# Evaluate model against trained data
# accuracy: 79.41%
#
# Evaluate model against new data
# accuracy: 78.99%
#
#
# # Fold 4
#
# Evaluate model against trained data
# accuracy: 81.72%
#
# Evaluate model against new data
# accuracy: 80.25%

# %% [markdown]
# # Model Evaluation

# %%
from keras import models
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, recall_score

# %%
fold = 0

for train, test in kf.split(X, Y):
  print("# Fold {}\n".format(fold))

  x_train = X.iloc[train]
  y_train = Y.iloc[train]
  x_test = X.iloc[test]
  y_test = Y.iloc[test]

  model_path = "{}best_trained_model_{}.h5".format(save_dir, fold)
  print("Model: {}".format(model_path))
  model = models.load_model(model_path)

  loss, accuracy = model.evaluate(x_test, y_test, verbose=0)

  # prediction return class type (1 or 0)
  y_pred_class = (model.predict(x_test) > 0.5).astype("int32")
  # prediction return proability percentage
  y_pred_prob = model.predict(x_test)

  cm = confusion_matrix(y_test, y_pred_class, labels=[0, 1])
  print("Simple confusion matrix\n", cm)

  print("Accuracy: %.2f%%" % (accuracy*100))

  print("Classification Report\n", classification_report(y_test, y_pred_class))

  print("\n")

  fold+=1
# Out:
# # Fold 0
#
# Model: /content/saved_models/best_trained_model_0.h5
# Simple confusion matrix
#  [[ 88  25]
#  [ 22 103]]
# Accuracy: 80.25%
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.80      0.78      0.79       113
#            1       0.80      0.82      0.81       125
#
#     accuracy                           0.80       238
#    macro avg       0.80      0.80      0.80       238
# weighted avg       0.80      0.80      0.80       238
#
#
#
# # Fold 1
#
# Model: /content/saved_models/best_trained_model_1.h5
# Simple confusion matrix
#  [[90 22]
#  [31 95]]
# Accuracy: 77.73%
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.74      0.80      0.77       112
#            1       0.81      0.75      0.78       126
#
#     accuracy                           0.78       238
#    macro avg       0.78      0.78      0.78       238
# weighted avg       0.78      0.78      0.78       238
#
#
#
# # Fold 2
#
# Model: /content/saved_models/best_trained_model_2.h5
# Simple confusion matrix
#  [[ 90  22]
#  [ 24 102]]
# Accuracy: 80.67%
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.79      0.80      0.80       112
#            1       0.82      0.81      0.82       126
#
#     accuracy                           0.81       238
#    macro avg       0.81      0.81      0.81       238
# weighted avg       0.81      0.81      0.81       238
#
#
#
# # Fold 3
#
# Model: /content/saved_models/best_trained_model_3.h5
# Simple confusion matrix
#  [[ 79  33]
#  [ 21 105]]
# Accuracy: 77.31%
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.79      0.71      0.75       112
#            1       0.76      0.83      0.80       126
#
#     accuracy                           0.77       238
#    macro avg       0.78      0.77      0.77       238
# weighted avg       0.77      0.77      0.77       238
#
#
#
# # Fold 4
#
# Model: /content/saved_models/best_trained_model_4.h5
# Simple confusion matrix
#  [[ 92  20]
#  [ 22 104]]
# Accuracy: 82.35%
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.81      0.82      0.81       112
#            1       0.84      0.83      0.83       126
#
#     accuracy                           0.82       238
#    macro avg       0.82      0.82      0.82       238
# weighted avg       0.82      0.82      0.82       238

# %% [markdown]
# # References
#
# https://keras.io/examples/structured_data/structured_data_classification_from_scratch/
#
# https://www.kaggle.com/anshigupta01/heart-disease-classification
#
# https://www.kaggle.com/mychen76/heart-disease-classification-with-keras
#
# https://www.kaggle.com/abdelsamad/heart-disease-prediction-with-neural-networks
